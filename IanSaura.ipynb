# %% [markdown]
# <a href="https://colab.research.google.com/github/jlescanog/bisso_tacna/blob/main/IanSaura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variables: Cajas para Guardar

# %%
anuncio = 'Hola Mundo'
print(anuncio)
# Out:
# Hola Mundo

# %%
nombre = 'Jhair'
edad = 33
edad_en_10_anios = edad + 10
print(f"Hola me llamo {nombre} y en 10 años tendré {edad_en_10_anios} años")
# Out:
# Hola me llamo Jhair y en 10 años tendré 43 años

# %% [markdown]
# Listas: Guardar Muchas Cosas

# %%
frutas = ["manzana", "pera", "platano"]

# %%
print(frutas)
# Out:
# ['manzana', 'pera', 'platano']

# %%
notas = [8,9,7,10,6]

# %%
print(sum(notas))
# Out:
# 40

# %%
print(len(notas))
# Out:
# 5

# %%
promedio = sum(notas)/len(notas)

# %%
print(f"Mi promedio de notas es: {promedio}")
# Out:
# Mi promedio de notas es: 8.0

# %% [markdown]
# Decisiones: Si pasa esto, hacé aquello

# %%
edad = 20

# %%
if edad > 18:
  print("Eres mayor de edad")
else:
  print("Eres menor de edad")
# Out:
# Eres mayor de edad

# %%
altura = 1.5

# %%
if altura > 1.8:
  print(f"Tu altura es: {altura}, puedes entrar")
else:
  print(f"Tu talla es : {altura}, no puedes entrar")
# Out:
# Tu talla es : 1.5, no puedes entrar

# %% [markdown]
# Repetir Acciones

# %%
amigos = ["Ana","Pedro","María","Lucas"]

# %% [markdown]
# ###for

# %%
for amigo in amigos:
  print(f"Hola soy {amigo}")
# Out:
# Hola soy Ana
# Hola soy Pedro
# Hola soy María
# Hola soy Lucas

# %% [markdown]
# ###range()

# %%
for i in range(5):
  print(f"Esta es la vuelta número: {i}")
# Out:
# Esta es la vuelta número: 0
# Esta es la vuelta número: 1
# Esta es la vuelta número: 2
# Esta es la vuelta número: 3
# Esta es la vuelta número: 4

# %% [markdown]
# #Funciones

# %%
def saludar(nombre):
  print(f"Hola {nombre}, bienvenido")

# %%
saludar("maria")
# Out:
# Hola maria, bienvenido

# %%
def calcular_doble(numero):
  return numero*2

# %%
resultado = calcular_doble(5)

# %%
print(resultado)
# Out:
# 10

# %%
print(calcular_doble(7))
# Out:
# 14

# %% [markdown]
# Ejercicio: Creá una función que calcule si alguien aprobó.

# %%
def aprueba(nota_alumno):
  if nota_alumno >= 6:
    print(f"El alumno aprueba con nota: {nota_alumno}")
  else:
    return "x Desaprobo"

# %%
print(aprueba(3))
# Out:
# x Desaprobo

# %% [markdown]
# Diccionarios: Datos Organizados

# %%
alumno = {"nombre":"Ana", "edad":16,"curso":"4to A"}

# %%
print(alumno['edad'])
# Out:
# 16

# %% [markdown]
# modificando los datos del diccionario

# %%
alumno["email"] = "ana@escuela.com"

# %%
print(alumno)
# Out:
# {'nombre': 'Ana', 'edad': 16, 'curso': '4to A', 'email': 'ana@escuela.com'}

# %%
alumno['edad'] = 23

# %%
print(alumno)
# Out:
# {'nombre': 'Ana', 'edad': 23, 'curso': '4to A', 'email': 'ana@escuela.com'}

# %% [markdown]
# Lista de diccionarios (muy común)

# %%
alumnos = [
    {"nombre":"Ana","nota": 10},
    {"nombre":"Pedro","nota": 9},
    {"nombre":"María","nota": 8}
]

# %%
print(alumnos)
# Out:
# [{'nombre': 'Ana', 'nota': 10}, {'nombre': 'Pedro', 'nota': 9}, {'nombre': 'María', 'nota': 8}]

# %%
print(alumnos[0])
# Out:
# {'nombre': 'Ana', 'nota': 10}

# %%
print(alumnos[0]["nombre"])
# Out:
# Ana

# %%
for alumno in alumnos:
  print(f"{alumno["nombre"]}:{alumno["nota"]}")
# Out:
# Ana:10
# Pedro:9
# María:8

# %% [markdown]
# ##Mini-Proyecto Python

# %%
notas = [10,2,7,10,10]

# %%
nombre = "Jhair Lescano"

# %%
promedio = sum(notas)/len(notas)

# %%
print(f"📊 Reporte de notas de {nombre}")
print(f"Notas: {notas}")
print(f"Promedio de notas: {promedio}")

if promedio >= 6:
  print(f"Felicitaciones aprobaste con. {promedio} de promedio")
else:
  print(f"No aprobaste con tu promedio: {promedio}")
# Out:
# 📊 Reporte de notas de Jhair Lescano
# Notas: [10, 2, 7, 10, 10]
# Promedio de notas: 7.8
# Felicitaciones aprobaste con. 7.8 de promedio

# %% [markdown]
# Ejercicios

# %% [markdown]
# CONSIGNA
# Creá una lista con los cuadrados de los números del 1 al 10.

# %%
cuadrados = [numero**2 for numero in range(1,11)]

print(cuadrados)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %% [markdown]
# CONSIGNA
# Contá la frecuencia de cada palabra en una lista.

# %%
palabras = ['python', 'data', 'python', 'sql', 'data', 'python']
